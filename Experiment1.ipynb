# %%
# %%writefile processCreation.sh
# #!/bin/bash
# echo "Parent Process Id:$$"
# (echo "Child 1 Process Id:$$, Parent Process ID:$PPID"
#  sleep 5) &
# (echo "Child 2 Process Id:$$, Parent Process ID:$PPID",
#  sleep 5)&
# sleep 1
# echo -e"\n Process Tree:"
# ps -o pid,ppid,cmd --forest |grep -E "bash|sleep" | grep -v "grep"
# Out:
# Overwriting processCreation.sh

# %%
# !chmod +x processCreation.sh

# %%
# !bash processCreation.sh
# Out:
# Parent Process Id:6455
# Child 1 Process Id:6455, Parent Process ID:297
# Child 2 Process Id:6455, Parent Process ID:297,
# -e\n Process Tree:
#       8       6  \_ /bin/bash -e /usr/local/colab/bin/oom_monitor.sh
#    6464       8  |   \_ sleep 1
#    6455     297  |       \_ bash processCreation.sh
#    6456    6455  |           \_ bash processCreation.sh
#    6460    6456  |           |   \_ sleep 5
#    6457    6455  |           \_ bash processCreation.sh
#    6459    6457  |           |   \_ sleep 5
#      10       1 /bin/bash -e /datalab/run.sh
